# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, balanced_accuracy_score, f1_score, roc_auc_score, ConfusionMatrixDisplay

# %%
df = pd.read_csv("/Users/EthanMcElhone/Downloads/data-1.csv") 
df.head()
# Out:
#                land_type  p_x  p_y  Band_1  Band_2  Band_3  Band_4  Band_5  \
# 0  valley floor / meadow    0    0  0.0174  0.0131  0.0108  0.0133  0.0158
# 1  valley floor / meadow    1    0  0.0180  0.0124  0.0116  0.0143  0.0154
# 2  valley floor / meadow    2    0  0.0151  0.0150  0.0113  0.0158  0.0167
# 3  valley floor / meadow    3    0  0.0172  0.0149  0.0095  0.0156  0.0154
# 4  valley floor / meadow    4    0  0.0184  0.0149  0.0143  0.0189  0.0174
#
#    Band_6  Band_7  ...  Band_211  Band_212  Band_213  Band_214  Band_215  \
# 0  0.0144  0.0151  ...    0.0237    0.0231    0.0224    0.0246    0.0255
# 1  0.0136  0.0151  ...    0.0289    0.0275    0.0288    0.0293    0.0286
# 2  0.0158  0.0163  ...    0.0358    0.0319    0.0355    0.0274    0.0303
# 3  0.0169  0.0176  ...    0.0310    0.0294    0.0307    0.0238    0.0304
# 4  0.0174  0.0182  ...    0.0428    0.0372    0.0407    0.0344    0.0415
#
#    Band_216  Band_217  Band_218  rgb_hex  overlay_hex
# 0    0.0174    0.0234    0.0147  #030B05    #25C77140
# 1    0.0211    0.0229    0.0176  #040A09    #25C77140
# 2    0.0232    0.0282    0.0181  #08110B    #25C77140
# 3    0.0232    0.0247    0.0087  #0C160C    #25C77140
# 4    0.0287    0.0317    0.0176  #0E180C    #25C77140
#
# [5 rows x 223 columns]

# %%
df["land_type"].unique()
# Out:
# array(['valley floor / meadow', 'alpine meadow', 'alpine tundra',
#        'veg-scree mix', 'bare rock', 'scree / sunlit rock', 'dark rock',
#        'snow / ice'], dtype=object)

# %%
land_mapping = {
    'valley floor / meadow': 0,
    'alpine meadow': 1,
    'alpine tundra': 2,
    'veg-scree mix': 3,
    'bare rock': 4,
    'scree / sunlit rock': 5,
    'dark rock': 6,
    'snow / ice': 7
}

df["land_type"] = df["land_type"].map(land_mapping)

# %%
df["land_type"].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
Y = df["land_type"]

X = df.drop(columns = ["land_type", "rgb_hex", "overlay_hex"])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size = 0.2, random_state = 42, stratify = Y)

# %%
xgb = xgb.XGBClassifier(
    objective = 'multi:softprob',    
    n_estimators = 300,
    max_depth = 6,
    learning_rate = 0.1,
    seed = 42,
    eval_metric = 'mlogloss',        
    early_stopping_rounds = 10,
    missing = np.nan)


xgb.fit(
    X_train,
    Y_train,
    eval_set = [(X_test, Y_test)],
    verbose = True)
# Out:
# [0]	validation_0-mlogloss:1.74121
# [1]	validation_0-mlogloss:1.52307
# [2]	validation_0-mlogloss:1.35346
# [3]	validation_0-mlogloss:1.21611
# [4]	validation_0-mlogloss:1.10041
# [5]	validation_0-mlogloss:1.00177
# [6]	validation_0-mlogloss:0.91554
# [7]	validation_0-mlogloss:0.84009
# [8]	validation_0-mlogloss:0.77354
# [9]	validation_0-mlogloss:0.71360
# [10]	validation_0-mlogloss:0.66025
# [11]	validation_0-mlogloss:0.61338
# [12]	validation_0-mlogloss:0.57041
# [13]	validation_0-mlogloss:0.53139
# [14]	validation_0-mlogloss:0.49559
# [15]	validation_0-mlogloss:0.46433
# [16]	validation_0-mlogloss:0.43548
# [17]	validation_0-mlogloss:0.40857
# [18]	validation_0-mlogloss:0.38434
# [19]	validation_0-mlogloss:0.36249
# [20]	validation_0-mlogloss:0.34153
# [21]	validation_0-mlogloss:0.32295
# [22]	validation_0-mlogloss:0.30612
# [23]	validation_0-mlogloss:0.29033
# [24]	validation_0-mlogloss:0.27608
# [25]	validation_0-mlogloss:0.26315
# [26]	validation_0-mlogloss:0.25086
# [27]	validation_0-mlogloss:0.23960
# [28]	validation_0-mlogloss:0.22953
# [29]	validation_0-mlogloss:0.21950
# [30]	validation_0-mlogloss:0.21063
# [31]	validation_0-mlogloss:0.20233
# [32]	validation_0-mlogloss:0.19551
# [33]	validation_0-mlogloss:0.18827
# [34]	validation_0-mlogloss:0.18182
# [35]	validation_0-mlogloss:0.17567
# [36]	validation_0-mlogloss:0.17009
# [37]	validation_0-mlogloss:0.16488
# [38]	validation_0-mlogloss:0.15956
# [39]	validation_0-mlogloss:0.15500
# [40]	validation_0-mlogloss:0.15052
# [41]	validation_0-mlogloss:0.14662
# [42]	validation_0-mlogloss:0.14289
# [43]	validation_0-mlogloss:0.13901
# [44]	validation_0-mlogloss:0.13585
# [45]	validation_0-mlogloss:0.13227
# [46]	validation_0-mlogloss:0.12910
# [47]	validation_0-mlogloss:0.12607
# [48]	validation_0-mlogloss:0.12319
# [49]	validation_0-mlogloss:0.12031
# [50]	validation_0-mlogloss:0.11807
# [51]	validation_0-mlogloss:0.11545
# [52]	validation_0-mlogloss:0.11330
# [53]	validation_0-mlogloss:0.11088
# [54]	validation_0-mlogloss:0.10872
# [55]	validation_0-mlogloss:0.10673
# [56]	validation_0-mlogloss:0.10468
# [57]	validation_0-mlogloss:0.10297
# [58]	validation_0-mlogloss:0.10141
# [59]	validation_0-mlogloss:0.09968
# [60]	validation_0-mlogloss:0.09803
# [61]	validation_0-mlogloss:0.09639
# [62]	validation_0-mlogloss:0.09498
# [63]	validation_0-mlogloss:0.09364
# [64]	validation_0-mlogloss:0.09229
# [65]	validation_0-mlogloss:0.09101
# [66]	validation_0-mlogloss:0.08989
# [67]	validation_0-mlogloss:0.08868
# [68]	validation_0-mlogloss:0.08772
# [69]	validation_0-mlogloss:0.08660
# [70]	validation_0-mlogloss:0.08568
# [71]	validation_0-mlogloss:0.08446
# [72]	validation_0-mlogloss:0.08358
# [73]	validation_0-mlogloss:0.08277
# [74]	validation_0-mlogloss:0.08181
# [75]	validation_0-mlogloss:0.08099
# [76]	validation_0-mlogloss:0.08027
# [77]	validation_0-mlogloss:0.07948
# [78]	validation_0-mlogloss:0.07895
# [79]	validation_0-mlogloss:0.07841
# [80]	validation_0-mlogloss:0.07754
# [81]	validation_0-mlogloss:0.07688
# [82]	validation_0-mlogloss:0.07627
# [83]	validation_0-mlogloss:0.07577
# [84]	validation_0-mlogloss:0.07506
# [85]	validation_0-mlogloss:0.07452
# [86]	validation_0-mlogloss:0.07398
# [87]	validation_0-mlogloss:0.07341
# [88]	validation_0-mlogloss:0.07292
# [89]	validation_0-mlogloss:0.07226
# [90]	validation_0-mlogloss:0.07177
# [91]	validation_0-mlogloss:0.07141
# [92]	validation_0-mlogloss:0.07088
# [93]	validation_0-mlogloss:0.07046
# [94]	validation_0-mlogloss:0.06997
# [95]	validation_0-mlogloss:0.06959
# [96]	validation_0-mlogloss:0.06908
# [97]	validation_0-mlogloss:0.06867
# [98]	validation_0-mlogloss:0.06817
# [99]	validation_0-mlogloss:0.06765
# [100]	validation_0-mlogloss:0.06719
# [101]	validation_0-mlogloss:0.06673
# [102]	validation_0-mlogloss:0.06634
# [103]	validation_0-mlogloss:0.06596
# [104]	validation_0-mlogloss:0.06546
# [105]	validation_0-mlogloss:0.06506
# [106]	validation_0-mlogloss:0.06456
# [107]	validation_0-mlogloss:0.06421
# [108]	validation_0-mlogloss:0.06386
# [109]	validation_0-mlogloss:0.06354
# [110]	validation_0-mlogloss:0.06322
# [111]	validation_0-mlogloss:0.06282
# [112]	validation_0-mlogloss:0.06227
# [113]	validation_0-mlogloss:0.06195
# [114]	validation_0-mlogloss:0.06144
# [115]	validation_0-mlogloss:0.06106
# [116]	validation_0-mlogloss:0.06085
# [117]	validation_0-mlogloss:0.06050
# [118]	validation_0-mlogloss:0.06017
# [119]	validation_0-mlogloss:0.05984
# [120]	validation_0-mlogloss:0.05951
# [121]	validation_0-mlogloss:0.05912
# [122]	validation_0-mlogloss:0.05876
# [123]	validation_0-mlogloss:0.05842
# [124]	validation_0-mlogloss:0.05817
# [125]	validation_0-mlogloss:0.05780
# [126]	validation_0-mlogloss:0.05749
# [127]	validation_0-mlogloss:0.05715
# [128]	validation_0-mlogloss:0.05692
# [129]	validation_0-mlogloss:0.05669
# [130]	validation_0-mlogloss:0.05657
# [131]	validation_0-mlogloss:0.05633
# [132]	validation_0-mlogloss:0.05603
# [133]	validation_0-mlogloss:0.05573
# [134]	validation_0-mlogloss:0.05546
# [135]	validation_0-mlogloss:0.05522
# [136]	validation_0-mlogloss:0.05500
# [137]	validation_0-mlogloss:0.05464
# [138]	validation_0-mlogloss:0.05447
# [139]	validation_0-mlogloss:0.05426
# [140]	validation_0-mlogloss:0.05415
# [141]	validation_0-mlogloss:0.05399
# [142]	validation_0-mlogloss:0.05382
# [143]	validation_0-mlogloss:0.05363
# [144]	validation_0-mlogloss:0.05331
# [145]	validation_0-mlogloss:0.05313
# [146]	validation_0-mlogloss:0.05290
# [147]	validation_0-mlogloss:0.05270
# [148]	validation_0-mlogloss:0.05253
# [149]	validation_0-mlogloss:0.05226
# [150]	validation_0-mlogloss:0.05204
# [151]	validation_0-mlogloss:0.05182
# [152]	validation_0-mlogloss:0.05172
# [153]	validation_0-mlogloss:0.05152
# [154]	validation_0-mlogloss:0.05136
# [155]	validation_0-mlogloss:0.05119
# [156]	validation_0-mlogloss:0.05111
# [157]	validation_0-mlogloss:0.05097
# [158]	validation_0-mlogloss:0.05083
# [159]	validation_0-mlogloss:0.05068
# [160]	validation_0-mlogloss:0.05059
# [161]	validation_0-mlogloss:0.05046
# [162]	validation_0-mlogloss:0.05034
# [163]	validation_0-mlogloss:0.05017
# [164]	validation_0-mlogloss:0.05005
# [165]	validation_0-mlogloss:0.04988
# [166]	validation_0-mlogloss:0.04975
# [167]	validation_0-mlogloss:0.04964
# [168]	validation_0-mlogloss:0.04950
# [169]	validation_0-mlogloss:0.04937
# [170]	validation_0-mlogloss:0.04927
# [171]	validation_0-mlogloss:0.04912
# [172]	validation_0-mlogloss:0.04904
# [173]	validation_0-mlogloss:0.04893
# [174]	validation_0-mlogloss:0.04876
# [175]	validation_0-mlogloss:0.04865
# [176]	validation_0-mlogloss:0.04851
# [177]	validation_0-mlogloss:0.04837
# [178]	validation_0-mlogloss:0.04825
# [179]	validation_0-mlogloss:0.04814
# [180]	validation_0-mlogloss:0.04800
# [181]	validation_0-mlogloss:0.04793
# [182]	validation_0-mlogloss:0.04785
# [183]	validation_0-mlogloss:0.04769
# [184]	validation_0-mlogloss:0.04763
# [185]	validation_0-mlogloss:0.04752
# [186]	validation_0-mlogloss:0.04742
# [187]	validation_0-mlogloss:0.04730
# [188]	validation_0-mlogloss:0.04719
# [189]	validation_0-mlogloss:0.04703
# [190]	validation_0-mlogloss:0.04696
# [191]	validation_0-mlogloss:0.04684
# [192]	validation_0-mlogloss:0.04675
# [193]	validation_0-mlogloss:0.04667
# [194]	validation_0-mlogloss:0.04661
# [195]	validation_0-mlogloss:0.04648
# [196]	validation_0-mlogloss:0.04637
# [197]	validation_0-mlogloss:0.04628
# [198]	validation_0-mlogloss:0.04620
# [199]	validation_0-mlogloss:0.04607
# [200]	validation_0-mlogloss:0.04599
# [201]	validation_0-mlogloss:0.04591
# [202]	validation_0-mlogloss:0.04583
# [203]	validation_0-mlogloss:0.04575
# [204]	validation_0-mlogloss:0.04567
# [205]	validation_0-mlogloss:0.04560
# [206]	validation_0-mlogloss:0.04550
# [207]	validation_0-mlogloss:0.04543
# [208]	validation_0-mlogloss:0.04532
# [209]	validation_0-mlogloss:0.04519
# [210]	validation_0-mlogloss:0.04509
# [211]	validation_0-mlogloss:0.04499
# [212]	validation_0-mlogloss:0.04491
# [213]	validation_0-mlogloss:0.04482
# [214]	validation_0-mlogloss:0.04477
# [215]	validation_0-mlogloss:0.04469
# [216]	validation_0-mlogloss:0.04460
# [217]	validation_0-mlogloss:0.04451
# [218]	validation_0-mlogloss:0.04440
# [219]	validation_0-mlogloss:0.04435
# [220]	validation_0-mlogloss:0.04427
# [221]	validation_0-mlogloss:0.04420
# [222]	validation_0-mlogloss:0.04414
# [223]	validation_0-mlogloss:0.04402
# [224]	validation_0-mlogloss:0.04395
# [225]	validation_0-mlogloss:0.04389
# [226]	validation_0-mlogloss:0.04380
# [227]	validation_0-mlogloss:0.04376
# [228]	validation_0-mlogloss:0.04364
# [229]	validation_0-mlogloss:0.04355
# [230]	validation_0-mlogloss:0.04349
# [231]	validation_0-mlogloss:0.04343
# [232]	validation_0-mlogloss:0.04333
# [233]	validation_0-mlogloss:0.04327
# [234]	validation_0-mlogloss:0.04322
# [235]	validation_0-mlogloss:0.04318
# [236]	validation_0-mlogloss:0.04312
# [237]	validation_0-mlogloss:0.04305
# [238]	validation_0-mlogloss:0.04299
# [239]	validation_0-mlogloss:0.04292
# [240]	validation_0-mlogloss:0.04288
# [241]	validation_0-mlogloss:0.04285
# [242]	validation_0-mlogloss:0.04277
# [243]	validation_0-mlogloss:0.04272
# [244]	validation_0-mlogloss:0.04264
# [245]	validation_0-mlogloss:0.04259
# [246]	validation_0-mlogloss:0.04253
# [247]	validation_0-mlogloss:0.04247
# [248]	validation_0-mlogloss:0.04244
# [249]	validation_0-mlogloss:0.04240
# [250]	validation_0-mlogloss:0.04235
# [251]	validation_0-mlogloss:0.04232
# [252]	validation_0-mlogloss:0.04225
# [253]	validation_0-mlogloss:0.04218
# [254]	validation_0-mlogloss:0.04214
# [255]	validation_0-mlogloss:0.04208
# [256]	validation_0-mlogloss:0.04205
# [257]	validation_0-mlogloss:0.04200
# [258]	validation_0-mlogloss:0.04195
# [259]	validation_0-mlogloss:0.04190
# [260]	validation_0-mlogloss:0.04185
# [261]	validation_0-mlogloss:0.04177
# [262]	validation_0-mlogloss:0.04172
# [263]	validation_0-mlogloss:0.04169
# [264]	validation_0-mlogloss:0.04163
# [265]	validation_0-mlogloss:0.04159
# [266]	validation_0-mlogloss:0.04154
# [267]	validation_0-mlogloss:0.04150
# [268]	validation_0-mlogloss:0.04146
# [269]	validation_0-mlogloss:0.04142
# [270]	validation_0-mlogloss:0.04139
# [271]	validation_0-mlogloss:0.04133
# [272]	validation_0-mlogloss:0.04127
# [273]	validation_0-mlogloss:0.04124
# [274]	validation_0-mlogloss:0.04120
# [275]	validation_0-mlogloss:0.04113
# [276]	validation_0-mlogloss:0.04107
# [277]	validation_0-mlogloss:0.04106
# [278]	validation_0-mlogloss:0.04102
# [279]	validation_0-mlogloss:0.04100
# [280]	validation_0-mlogloss:0.04096
# [281]	validation_0-mlogloss:0.04092
# [282]	validation_0-mlogloss:0.04086
# [283]	validation_0-mlogloss:0.04083
# [284]	validation_0-mlogloss:0.04080
# [285]	validation_0-mlogloss:0.04076
# [286]	validation_0-mlogloss:0.04073
# [287]	validation_0-mlogloss:0.04068
# [288]	validation_0-mlogloss:0.04064
# [289]	validation_0-mlogloss:0.04059
# [290]	validation_0-mlogloss:0.04050
# [291]	validation_0-mlogloss:0.04043
# [292]	validation_0-mlogloss:0.04038
# [293]	validation_0-mlogloss:0.04033
# [294]	validation_0-mlogloss:0.04032
# [295]	validation_0-mlogloss:0.04030
# [296]	validation_0-mlogloss:0.04025
# [297]	validation_0-mlogloss:0.04022
# [298]	validation_0-mlogloss:0.04017
# [299]	validation_0-mlogloss:0.04012
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
print("Best iteration:", xgb.get_booster().best_iteration)
print("Best score:", xgb.get_booster().best_score)
# Out:
# Best iteration: 299
# Best score: 0.04012439339227797

# %%
Y_test = pd.DataFrame(Y_test)

Y_test["predicted"] =  xgb.predict(X_test)

Y_test
# Out:
#         land_type  predicted
# 19906           2          2
# 124630          2          2
# 160459          3          3
# 123665          0          0
# 120034          5          5
# ...           ...        ...
# 121799          3          3
# 49550           2          2
# 67010           2          2
# 73533           0          0
# 153899          2          2
#
# [43121 rows x 2 columns]

# %%
land_type = ["valley floor / meadow (0)", "alpine meadow (1)", "alpine tundra (2)", "veg-scree mix (3)", 
             "bare rock (4)", "scree / sunlit rock (5)", "dark rock (6)", "snow / ice (7)"]

fig, ax = plt.subplots(figsize=(30, 20))

Confusion_Matrix = ConfusionMatrixDisplay.from_predictions(y_true = Y_test["land_type"],
                                                           y_pred = Y_test["predicted"],
                                                           labels = [0,1,2,3,4,5,6,7],
                                                           display_labels = land_type,
                                                           colorbar = False,
                                                           cmap = "Blues",
                                                           ax = ax)

plt.xlabel("Predicted")
plt.ylabel("Actual")
ax = Confusion_Matrix.ax_
ax.xaxis.set_ticks_position("top")
ax.xaxis.set_label_position("top")
plt.show()

# %%
misclassification = 1 - accuracy_score(Y_test["land_type"], Y_test["predicted"])
print(f"Overall Misclassification Error Rate: {misclassification:4f}")
# Out:
# Overall Misclassification Error Rate: 0.015143

# %%
precision_macro = precision_score(Y_test["land_type"], Y_test["predicted"], average='macro')
print(f"Macro-Average Precision: {precision_macro:.4f}")

precision_weighted = precision_score(Y_test["land_type"], Y_test["predicted"], average='weighted')
print(f"Weighted-Average Precision: {precision_weighted:.4f}")
# Out:
# Macro-Average Precision: 0.9840
# Weighted-Average Precision: 0.9849

# %%
recall_macro = recall_score(Y_test["land_type"], Y_test["predicted"], average='macro')
print(f"Macro-Average Recall: {recall_macro:4f}")

recall_weighted = recall_score(Y_test["land_type"], Y_test["predicted"], average='weighted')
print(f"Weighted-Average Recall: {recall_weighted:4f}")
# Out:
# Macro-Average Recall: 0.984098
# Weighted-Average Recall: 0.984857

# %%
y_true = Y_test["land_type"].values
y_pred = Y_test["predicted"].values
y_prob = xgb.predict_proba(X_test) 

balanced_accuracies = []
f1_scores = []
aucs = []

for k in range(8):
    y_true_k = (y_true == k).astype(int)
    y_pred_k = (y_pred == k).astype(int)
    y_prob_k = y_prob[:, k]
    
    balanced_accuracies.append(balanced_accuracy_score(y_true_k, y_pred_k))
    f1_scores.append(f1_score(y_true_k, y_pred_k))
    aucs.append(roc_auc_score(y_true_k, y_prob_k))

avg_balanced_accuracy = np.mean(balanced_accuracies)
avg_f1 = np.mean(f1_scores)
avg_auc = np.mean(aucs)

print(f"Average Balanced Accuracy: {avg_balanced_accuracy:4f}")
print(f"Average F1 Score: {avg_f1:4f}")
print(f"Average AUC: {avg_auc:4f}")
# Out:
# Average Balanced Accuracy: 0.990931
# Average F1 Score: 0.984055
# Average AUC: 0.999867
