# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, balanced_accuracy_score, f1_score, roc_auc_score, ConfusionMatrixDisplay

# %%
df = pd.read_csv("/Users/EthanMcElhone/Downloads/data-1.csv") 
df.head()
# Out:
#                land_type  p_x  p_y  Band_1  Band_2  Band_3  Band_4  Band_5  \
# 0  valley floor / meadow    0    0  0.0174  0.0131  0.0108  0.0133  0.0158
# 1  valley floor / meadow    1    0  0.0180  0.0124  0.0116  0.0143  0.0154
# 2  valley floor / meadow    2    0  0.0151  0.0150  0.0113  0.0158  0.0167
# 3  valley floor / meadow    3    0  0.0172  0.0149  0.0095  0.0156  0.0154
# 4  valley floor / meadow    4    0  0.0184  0.0149  0.0143  0.0189  0.0174
#
#    Band_6  Band_7  ...  Band_211  Band_212  Band_213  Band_214  Band_215  \
# 0  0.0144  0.0151  ...    0.0237    0.0231    0.0224    0.0246    0.0255
# 1  0.0136  0.0151  ...    0.0289    0.0275    0.0288    0.0293    0.0286
# 2  0.0158  0.0163  ...    0.0358    0.0319    0.0355    0.0274    0.0303
# 3  0.0169  0.0176  ...    0.0310    0.0294    0.0307    0.0238    0.0304
# 4  0.0174  0.0182  ...    0.0428    0.0372    0.0407    0.0344    0.0415
#
#    Band_216  Band_217  Band_218  rgb_hex  overlay_hex
# 0    0.0174    0.0234    0.0147  #030B05    #25C77140
# 1    0.0211    0.0229    0.0176  #040A09    #25C77140
# 2    0.0232    0.0282    0.0181  #08110B    #25C77140
# 3    0.0232    0.0247    0.0087  #0C160C    #25C77140
# 4    0.0287    0.0317    0.0176  #0E180C    #25C77140
#
# [5 rows x 223 columns]

# %%
df["land_type"].unique()
# Out:
# array(['valley floor / meadow', 'alpine meadow', 'alpine tundra',
#        'veg-scree mix', 'bare rock', 'scree / sunlit rock', 'dark rock',
#        'snow / ice'], dtype=object)

# %%
land_mapping = {
    'valley floor / meadow': 0,
    'alpine meadow': 1,
    'alpine tundra': 2,
    'veg-scree mix': 3,
    'bare rock': 4,
    'scree / sunlit rock': 5,
    'dark rock': 6,
    'snow / ice': 7
}

df["land_type"] = df["land_type"].map(land_mapping)

# %%
df["land_type"].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
Y = df["land_type"]

X = df.drop(columns = ["land_type", "rgb_hex", "overlay_hex"])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size = 0.2, random_state = 42, stratify = Y)

# %%
apply_pca = True

if apply_pca:
    pca = PCA(n_components = 10, random_state=42)
    X_train = pca.fit_transform(X_train)
    X_test = pca.transform(X_test)

# %%
xgb = xgb.XGBClassifier(
    objective = 'multi:softprob',    
    n_estimators = 300,
    max_depth = 6,
    learning_rate = 0.1,
    seed = 42,
    eval_metric = 'mlogloss',        
    early_stopping_rounds = 10,
    missing = np.nan)


xgb.fit(
    X_train,
    Y_train,
    eval_set = [(X_test, Y_test)],
    verbose = True)
# Out:
# [0]	validation_0-mlogloss:1.82771
# [1]	validation_0-mlogloss:1.66228
# [2]	validation_0-mlogloss:1.52873
# [3]	validation_0-mlogloss:1.41461
# [4]	validation_0-mlogloss:1.31748
# [5]	validation_0-mlogloss:1.23155
# [6]	validation_0-mlogloss:1.15729
# [7]	validation_0-mlogloss:1.09119
# [8]	validation_0-mlogloss:1.03279
# [9]	validation_0-mlogloss:0.97923
# [10]	validation_0-mlogloss:0.93137
# [11]	validation_0-mlogloss:0.88776
# [12]	validation_0-mlogloss:0.84841
# [13]	validation_0-mlogloss:0.81251
# [14]	validation_0-mlogloss:0.77834
# [15]	validation_0-mlogloss:0.74866
# [16]	validation_0-mlogloss:0.72066
# [17]	validation_0-mlogloss:0.69416
# [18]	validation_0-mlogloss:0.66982
# [19]	validation_0-mlogloss:0.64622
# [20]	validation_0-mlogloss:0.62441
# [21]	validation_0-mlogloss:0.60386
# [22]	validation_0-mlogloss:0.58378
# [23]	validation_0-mlogloss:0.56454
# [24]	validation_0-mlogloss:0.54728
# [25]	validation_0-mlogloss:0.53160
# [26]	validation_0-mlogloss:0.51418
# [27]	validation_0-mlogloss:0.49928
# [28]	validation_0-mlogloss:0.48432
# [29]	validation_0-mlogloss:0.47137
# [30]	validation_0-mlogloss:0.45797
# [31]	validation_0-mlogloss:0.44535
# [32]	validation_0-mlogloss:0.43394
# [33]	validation_0-mlogloss:0.42256
# [34]	validation_0-mlogloss:0.41187
# [35]	validation_0-mlogloss:0.40156
# [36]	validation_0-mlogloss:0.39120
# [37]	validation_0-mlogloss:0.38309
# [38]	validation_0-mlogloss:0.37437
# [39]	validation_0-mlogloss:0.36579
# [40]	validation_0-mlogloss:0.35770
# [41]	validation_0-mlogloss:0.35028
# [42]	validation_0-mlogloss:0.34340
# [43]	validation_0-mlogloss:0.33628
# [44]	validation_0-mlogloss:0.32950
# [45]	validation_0-mlogloss:0.32318
# [46]	validation_0-mlogloss:0.31654
# [47]	validation_0-mlogloss:0.31130
# [48]	validation_0-mlogloss:0.30598
# [49]	validation_0-mlogloss:0.30091
# [50]	validation_0-mlogloss:0.29563
# [51]	validation_0-mlogloss:0.29054
# [52]	validation_0-mlogloss:0.28619
# [53]	validation_0-mlogloss:0.28200
# [54]	validation_0-mlogloss:0.27786
# [55]	validation_0-mlogloss:0.27358
# [56]	validation_0-mlogloss:0.26993
# [57]	validation_0-mlogloss:0.26626
# [58]	validation_0-mlogloss:0.26269
# [59]	validation_0-mlogloss:0.25964
# [60]	validation_0-mlogloss:0.25626
# [61]	validation_0-mlogloss:0.25276
# [62]	validation_0-mlogloss:0.24980
# [63]	validation_0-mlogloss:0.24681
# [64]	validation_0-mlogloss:0.24373
# [65]	validation_0-mlogloss:0.24104
# [66]	validation_0-mlogloss:0.23821
# [67]	validation_0-mlogloss:0.23586
# [68]	validation_0-mlogloss:0.23349
# [69]	validation_0-mlogloss:0.23140
# [70]	validation_0-mlogloss:0.22945
# [71]	validation_0-mlogloss:0.22736
# [72]	validation_0-mlogloss:0.22520
# [73]	validation_0-mlogloss:0.22294
# [74]	validation_0-mlogloss:0.22071
# [75]	validation_0-mlogloss:0.21824
# [76]	validation_0-mlogloss:0.21607
# [77]	validation_0-mlogloss:0.21420
# [78]	validation_0-mlogloss:0.21204
# [79]	validation_0-mlogloss:0.21000
# [80]	validation_0-mlogloss:0.20836
# [81]	validation_0-mlogloss:0.20659
# [82]	validation_0-mlogloss:0.20493
# [83]	validation_0-mlogloss:0.20335
# [84]	validation_0-mlogloss:0.20127
# [85]	validation_0-mlogloss:0.19971
# [86]	validation_0-mlogloss:0.19825
# [87]	validation_0-mlogloss:0.19710
# [88]	validation_0-mlogloss:0.19558
# [89]	validation_0-mlogloss:0.19376
# [90]	validation_0-mlogloss:0.19251
# [91]	validation_0-mlogloss:0.19118
# [92]	validation_0-mlogloss:0.18982
# [93]	validation_0-mlogloss:0.18838
# [94]	validation_0-mlogloss:0.18726
# [95]	validation_0-mlogloss:0.18597
# [96]	validation_0-mlogloss:0.18453
# [97]	validation_0-mlogloss:0.18322
# [98]	validation_0-mlogloss:0.18204
# [99]	validation_0-mlogloss:0.18080
# [100]	validation_0-mlogloss:0.17977
# [101]	validation_0-mlogloss:0.17871
# [102]	validation_0-mlogloss:0.17744
# [103]	validation_0-mlogloss:0.17612
# [104]	validation_0-mlogloss:0.17503
# [105]	validation_0-mlogloss:0.17378
# [106]	validation_0-mlogloss:0.17242
# [107]	validation_0-mlogloss:0.17150
# [108]	validation_0-mlogloss:0.17051
# [109]	validation_0-mlogloss:0.16958
# [110]	validation_0-mlogloss:0.16838
# [111]	validation_0-mlogloss:0.16741
# [112]	validation_0-mlogloss:0.16644
# [113]	validation_0-mlogloss:0.16556
# [114]	validation_0-mlogloss:0.16468
# [115]	validation_0-mlogloss:0.16364
# [116]	validation_0-mlogloss:0.16273
# [117]	validation_0-mlogloss:0.16186
# [118]	validation_0-mlogloss:0.16102
# [119]	validation_0-mlogloss:0.16022
# [120]	validation_0-mlogloss:0.15927
# [121]	validation_0-mlogloss:0.15857
# [122]	validation_0-mlogloss:0.15774
# [123]	validation_0-mlogloss:0.15676
# [124]	validation_0-mlogloss:0.15612
# [125]	validation_0-mlogloss:0.15515
# [126]	validation_0-mlogloss:0.15437
# [127]	validation_0-mlogloss:0.15369
# [128]	validation_0-mlogloss:0.15296
# [129]	validation_0-mlogloss:0.15212
# [130]	validation_0-mlogloss:0.15138
# [131]	validation_0-mlogloss:0.15080
# [132]	validation_0-mlogloss:0.15011
# [133]	validation_0-mlogloss:0.14955
# [134]	validation_0-mlogloss:0.14880
# [135]	validation_0-mlogloss:0.14810
# [136]	validation_0-mlogloss:0.14745
# [137]	validation_0-mlogloss:0.14683
# [138]	validation_0-mlogloss:0.14626
# [139]	validation_0-mlogloss:0.14571
# [140]	validation_0-mlogloss:0.14513
# [141]	validation_0-mlogloss:0.14441
# [142]	validation_0-mlogloss:0.14392
# [143]	validation_0-mlogloss:0.14344
# [144]	validation_0-mlogloss:0.14288
# [145]	validation_0-mlogloss:0.14227
# [146]	validation_0-mlogloss:0.14185
# [147]	validation_0-mlogloss:0.14124
# [148]	validation_0-mlogloss:0.14061
# [149]	validation_0-mlogloss:0.14003
# [150]	validation_0-mlogloss:0.13951
# [151]	validation_0-mlogloss:0.13907
# [152]	validation_0-mlogloss:0.13844
# [153]	validation_0-mlogloss:0.13794
# [154]	validation_0-mlogloss:0.13754
# [155]	validation_0-mlogloss:0.13702
# [156]	validation_0-mlogloss:0.13653
# [157]	validation_0-mlogloss:0.13611
# [158]	validation_0-mlogloss:0.13558
# [159]	validation_0-mlogloss:0.13512
# [160]	validation_0-mlogloss:0.13471
# [161]	validation_0-mlogloss:0.13412
# [162]	validation_0-mlogloss:0.13367
# [163]	validation_0-mlogloss:0.13309
# [164]	validation_0-mlogloss:0.13260
# [165]	validation_0-mlogloss:0.13224
# [166]	validation_0-mlogloss:0.13185
# [167]	validation_0-mlogloss:0.13140
# [168]	validation_0-mlogloss:0.13099
# [169]	validation_0-mlogloss:0.13066
# [170]	validation_0-mlogloss:0.13021
# [171]	validation_0-mlogloss:0.12979
# [172]	validation_0-mlogloss:0.12940
# [173]	validation_0-mlogloss:0.12900
# [174]	validation_0-mlogloss:0.12866
# [175]	validation_0-mlogloss:0.12827
# [176]	validation_0-mlogloss:0.12791
# [177]	validation_0-mlogloss:0.12748
# [178]	validation_0-mlogloss:0.12713
# [179]	validation_0-mlogloss:0.12680
# [180]	validation_0-mlogloss:0.12647
# [181]	validation_0-mlogloss:0.12613
# [182]	validation_0-mlogloss:0.12572
# [183]	validation_0-mlogloss:0.12540
# [184]	validation_0-mlogloss:0.12502
# [185]	validation_0-mlogloss:0.12468
# [186]	validation_0-mlogloss:0.12442
# [187]	validation_0-mlogloss:0.12402
# [188]	validation_0-mlogloss:0.12369
# [189]	validation_0-mlogloss:0.12341
# [190]	validation_0-mlogloss:0.12303
# [191]	validation_0-mlogloss:0.12264
# [192]	validation_0-mlogloss:0.12236
# [193]	validation_0-mlogloss:0.12207
# [194]	validation_0-mlogloss:0.12175
# [195]	validation_0-mlogloss:0.12142
# [196]	validation_0-mlogloss:0.12113
# [197]	validation_0-mlogloss:0.12082
# [198]	validation_0-mlogloss:0.12045
# [199]	validation_0-mlogloss:0.12019
# [200]	validation_0-mlogloss:0.11991
# [201]	validation_0-mlogloss:0.11963
# [202]	validation_0-mlogloss:0.11926
# [203]	validation_0-mlogloss:0.11902
# [204]	validation_0-mlogloss:0.11868
# [205]	validation_0-mlogloss:0.11842
# [206]	validation_0-mlogloss:0.11808
# [207]	validation_0-mlogloss:0.11785
# [208]	validation_0-mlogloss:0.11748
# [209]	validation_0-mlogloss:0.11722
# [210]	validation_0-mlogloss:0.11694
# [211]	validation_0-mlogloss:0.11667
# [212]	validation_0-mlogloss:0.11650
# [213]	validation_0-mlogloss:0.11622
# [214]	validation_0-mlogloss:0.11597
# [215]	validation_0-mlogloss:0.11574
# [216]	validation_0-mlogloss:0.11547
# [217]	validation_0-mlogloss:0.11527
# [218]	validation_0-mlogloss:0.11497
# [219]	validation_0-mlogloss:0.11474
# [220]	validation_0-mlogloss:0.11447
# [221]	validation_0-mlogloss:0.11422
# [222]	validation_0-mlogloss:0.11405
# [223]	validation_0-mlogloss:0.11384
# [224]	validation_0-mlogloss:0.11353
# [225]	validation_0-mlogloss:0.11324
# [226]	validation_0-mlogloss:0.11298
# [227]	validation_0-mlogloss:0.11279
# [228]	validation_0-mlogloss:0.11254
# [229]	validation_0-mlogloss:0.11232
# [230]	validation_0-mlogloss:0.11207
# [231]	validation_0-mlogloss:0.11185
# [232]	validation_0-mlogloss:0.11165
# [233]	validation_0-mlogloss:0.11140
# [234]	validation_0-mlogloss:0.11118
# [235]	validation_0-mlogloss:0.11100
# [236]	validation_0-mlogloss:0.11077
# [237]	validation_0-mlogloss:0.11052
# [238]	validation_0-mlogloss:0.11025
# [239]	validation_0-mlogloss:0.11006
# [240]	validation_0-mlogloss:0.10987
# [241]	validation_0-mlogloss:0.10967
# [242]	validation_0-mlogloss:0.10945
# [243]	validation_0-mlogloss:0.10919
# [244]	validation_0-mlogloss:0.10903
# [245]	validation_0-mlogloss:0.10883
# [246]	validation_0-mlogloss:0.10864
# [247]	validation_0-mlogloss:0.10848
# [248]	validation_0-mlogloss:0.10825
# [249]	validation_0-mlogloss:0.10805
# [250]	validation_0-mlogloss:0.10786
# [251]	validation_0-mlogloss:0.10760
# [252]	validation_0-mlogloss:0.10744
# [253]	validation_0-mlogloss:0.10721
# [254]	validation_0-mlogloss:0.10707
# [255]	validation_0-mlogloss:0.10686
# [256]	validation_0-mlogloss:0.10677
# [257]	validation_0-mlogloss:0.10661
# [258]	validation_0-mlogloss:0.10644
# [259]	validation_0-mlogloss:0.10630
# [260]	validation_0-mlogloss:0.10620
# [261]	validation_0-mlogloss:0.10606
# [262]	validation_0-mlogloss:0.10592
# [263]	validation_0-mlogloss:0.10575
# [264]	validation_0-mlogloss:0.10548
# [265]	validation_0-mlogloss:0.10532
# [266]	validation_0-mlogloss:0.10515
# [267]	validation_0-mlogloss:0.10496
# [268]	validation_0-mlogloss:0.10480
# [269]	validation_0-mlogloss:0.10462
# [270]	validation_0-mlogloss:0.10444
# [271]	validation_0-mlogloss:0.10427
# [272]	validation_0-mlogloss:0.10413
# [273]	validation_0-mlogloss:0.10397
# [274]	validation_0-mlogloss:0.10382
# [275]	validation_0-mlogloss:0.10361
# [276]	validation_0-mlogloss:0.10350
# [277]	validation_0-mlogloss:0.10337
# [278]	validation_0-mlogloss:0.10327
# [279]	validation_0-mlogloss:0.10313
# [280]	validation_0-mlogloss:0.10294
# [281]	validation_0-mlogloss:0.10282
# [282]	validation_0-mlogloss:0.10270
# [283]	validation_0-mlogloss:0.10255
# [284]	validation_0-mlogloss:0.10241
# [285]	validation_0-mlogloss:0.10229
# [286]	validation_0-mlogloss:0.10217
# [287]	validation_0-mlogloss:0.10200
# [288]	validation_0-mlogloss:0.10189
# [289]	validation_0-mlogloss:0.10174
# [290]	validation_0-mlogloss:0.10163
# [291]	validation_0-mlogloss:0.10149
# [292]	validation_0-mlogloss:0.10131
# [293]	validation_0-mlogloss:0.10119
# [294]	validation_0-mlogloss:0.10101
# [295]	validation_0-mlogloss:0.10088
# [296]	validation_0-mlogloss:0.10073
# [297]	validation_0-mlogloss:0.10058
# [298]	validation_0-mlogloss:0.10046
# [299]	validation_0-mlogloss:0.10034
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
print("Best iteration:", xgb.get_booster().best_iteration)
print("Best score:", xgb.get_booster().best_score)
# Out:
# Best iteration: 299
# Best score: 0.10033818527128129

# %%
Y_test = pd.DataFrame(Y_test)

Y_test["predicted"] =  xgb.predict(X_test)

Y_test
# Out:
#         land_type  predicted
# 19906           2          2
# 124630          2          2
# 160459          3          3
# 123665          0          0
# 120034          5          5
# ...           ...        ...
# 121799          3          3
# 49550           2          2
# 67010           2          2
# 73533           0          0
# 153899          2          2
#
# [43121 rows x 2 columns]

# %%
land_type = ["valley floor / meadow (0)", "alpine meadow (1)", "alpine tundra (2)", "veg-scree mix (3)", 
             "bare rock (4)", "scree / sunlit rock (5)", "dark rock (6)", "snow / ice (7)"]

fig, ax = plt.subplots(figsize=(30, 20))

Confusion_Matrix = ConfusionMatrixDisplay.from_predictions(y_true = Y_test["land_type"],
                                                           y_pred = Y_test["predicted"],
                                                           labels = [0,1,2,3,4,5,6,7],
                                                           display_labels = land_type,
                                                           colorbar = False,
                                                           cmap = "Blues",
                                                           ax = ax)

plt.xlabel("Predicted")
plt.ylabel("Actual")
ax = Confusion_Matrix.ax_
ax.xaxis.set_ticks_position("top")
ax.xaxis.set_label_position("top")
plt.show()

# %%
misclassification = 1 - accuracy_score(Y_test["land_type"], Y_test["predicted"])
print(f"Overall Misclassification Error Rate: {misclassification:4f}")
# Out:
# Overall Misclassification Error Rate: 0.035899

# %%
precision_macro = precision_score(Y_test["land_type"], Y_test["predicted"], average='macro')
print(f"Macro-Average Precision: {precision_macro:.4f}")

precision_weighted = precision_score(Y_test["land_type"], Y_test["predicted"], average='weighted')
print(f"Weighted-Average Precision: {precision_weighted:.4f}")
# Out:
# Macro-Average Precision: 0.9655
# Weighted-Average Precision: 0.9641

# %%
recall_macro = recall_score(Y_test["land_type"], Y_test["predicted"], average='macro')
print(f"Macro-Average Recall: {recall_macro:4f}")

recall_weighted = recall_score(Y_test["land_type"], Y_test["predicted"], average='weighted')
print(f"Weighted-Average Recall: {recall_weighted:4f}")
# Out:
# Macro-Average Recall: 0.964333
# Weighted-Average Recall: 0.964101

# %%
y_true = Y_test["land_type"].values
y_pred = Y_test["predicted"].values
y_prob = xgb.predict_proba(X_test) 

balanced_accuracies = []
f1_scores = []
aucs = []

for k in range(8):
    y_true_k = (y_true == k).astype(int)
    y_pred_k = (y_pred == k).astype(int)
    y_prob_k = y_prob[:, k]
    
    balanced_accuracies.append(balanced_accuracy_score(y_true_k, y_pred_k))
    f1_scores.append(f1_score(y_true_k, y_pred_k))
    aucs.append(roc_auc_score(y_true_k, y_prob_k))

avg_balanced_accuracy = np.mean(balanced_accuracies)
avg_f1 = np.mean(f1_scores)
avg_auc = np.mean(aucs)

print(f"Average Balanced Accuracy: {avg_balanced_accuracy:4f}")
print(f"Average F1 Score: {avg_f1:4f}")
print(f"Average AUC: {avg_auc:4f}")
# Out:
# Average Balanced Accuracy: 0.979470
# Average F1 Score: 0.964924
# Average AUC: 0.999297
